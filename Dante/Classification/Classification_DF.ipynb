# %%
#Importing Data
from sklearn import tree
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import plot_confusion_matrix

data = pd.read_csv('breast-cancer.csv', delimiter = ',', skiprows = 1)

X = data.iloc[:,2:]
y = data.iloc[:,1:2]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8, random_state=4)

# %%
#Support Vector Machine Classifier
from sklearn import svm
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

clf = make_pipeline(StandardScaler(), SVC())

clf.fit(X_train, np.ravel(y_train))
y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
plot_confusion_matrix(clf, X_test, y_test)
# Out:
# Accuracy: 0.9758241758241758

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier

clf2 = RandomForestClassifier(n_estimators=44)
clf2 = clf2.fit(X_train, np.ravel(y_train))
y_pred = clf2.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
plot_confusion_matrix(clf2, X_test, y_test)
# Out:
# Accuracy: 0.9208791208791208

# %%
#Stochastic Gradient Descent Classifier
from sklearn.linear_model import SGDClassifier

clf3 = make_pipeline(StandardScaler(), SGDClassifier(loss="modified_huber", penalty="l2", max_iter=444))
clf3 = clf3.fit(X_train, np.ravel(y_train))
y_pred = clf3.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
plot_confusion_matrix(clf3, X_test, y_test)
# Out:
# Accuracy: 0.9648351648351648
